# %%
# %sql

TRUNCATE TABLE workspace.metadata.pipeline_control;

CREATE TABLE IF NOT EXISTS workspace.metadata.pipeline_control (
    table_name      STRING,
    file_name       STRING,
    active_flag     STRING,
    created_date    DATE,
    modified_date   DATE
);

INSERT INTO workspace.metadata.pipeline_control VALUES
('Album',           'Album',            'Y', current_date(), current_date()),
('Artist',          'Artist',           'Y', current_date(), current_date()),
('Customer',        'Customer',         'Y', current_date(), current_date()),
('Employee',        'Employee',         'Y', current_date(), current_date()),
('Genre',           'Genre',            'Y', current_date(), current_date()),
('Invoice',         'Invoice',          'Y', current_date(), current_date()),
('InvoiceLine',     'InvoiceLine',      'Y', current_date(), current_date()),
('MediaType',       'MediaType',        'Y', current_date(), current_date()),
('Playlist',        'Playlist',         'Y', current_date(), current_date()),
('PlaylistTrack',   'PlaylistTrack',    'Y', current_date(), current_date()),
('Track',           'Track',            'Y', current_date(), current_date());

CREATE TABLE IF NOT EXISTS workspace.metadata.execution_log (
    table_name          STRING,
    execution_time      TIMESTAMP,
    status              STRING,
    source_row_count    BIGINT,
    target_row_count    BIGINT,
    file_location       STRING,
    created_date        DATE
);

-- Verify
SELECT * FROM workspace.metadata.pipeline_control;
